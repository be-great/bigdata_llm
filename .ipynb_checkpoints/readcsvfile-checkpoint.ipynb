# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lower, trim

# %%
spark = SparkSession.builder.appName("HospitalCurate").getOrCreate()

# Read curated Parquet
df = spark.read.parquet("data/curated_parquet")

# Show in notebook (like CSV preview)
df.show(truncate=False)

# To see column names
df.printSchema()
# Out:
# 25/11/04 16:29:51 WARN Utils: Your hostname, Ahed resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/11/04 16:29:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/04 16:29:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/04 16:30:01 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...

# %%
df.head(20)
# Out:
# [Row(patient_id='p012', treatment_id='t014', appointment_id='a014', doctor_id='d010', appointment_date=datetime.date(2023, 5, 25), appointment_time=datetime.datetime(2025, 11, 4, 10, 30), reason_for_visit='emergency', status='cancelled', patient_first_name='laura', patient_last_name='davis', gender='f', date_of_birth=datetime.date(1991, 12, 8), contact_number=8135666049, address='321 maple dr', registration_date=datetime.date(2023, 4, 27), insurance_provider='medcare plus', insurance_number='ins104014', patient_email='laura.davis@mail.com', doctor_first_name='linda', doctor_last_name='wilson', specialization='oncology', phone_number=6176383634, years_experience=21, hospital_branch='eastside clinic', doctor_email='dr.linda.wilson@hospital.com', treatment_type='ecg', description='basic screening', cost=2082.3, treatment_date=datetime.date(2023, 5, 25), bill_id='b014', bill_date=datetime.date(2023, 5, 25), amount=2082.3, payment_method='credit card', payment_status='paid'),
# ...
